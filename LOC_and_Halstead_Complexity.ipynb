# %%
import json
import math
import ast

# Function to count lines of code
def count_loc(jsonl_file):
    loc_count = {}

    with open(jsonl_file, 'r') as f:
        for line in f:
            data = json.loads(line.strip())
            task_id = data.get('task_id')
            completion = data.get('completion')

            if task_id not in loc_count:
                loc_count[task_id] = 0

            # Count lines of code if completion exists
            if completion:
                loc_count[task_id] += completion.count('\n') + 1

    return loc_count

# Function to extract variable operands
def get_variable_operands(code):
    operands = set()
    operands_list = []

    try:
        tree = ast.parse(code)
        for node in ast.walk(tree):
            if isinstance(node, ast.Name):
                operands.add(node.id)
                operands_list.append(node.id)
    except SyntaxError:
        print("Syntax error in code, skipping operands extraction.")

    return operands, operands_list

# Function to calculate Halstead metrics
def calculate_halstead_metrics(completion):
    operators = [
        '+', '-', '*', '/', '//', '%', '**',
        '==', '!=', '>', '<', '>=', '<=',
        'and', 'or', 'not',
        '=', '+=', '-=', '*=', '/=', '//=', '%=', '**=',
        '&', '|', '^', '~', '<<', '>>',
        'in', 'not in',
        'is', 'is not'
    ]

    # Count operators and operands
    N1 = sum(1 for token in completion.split() if token in operators)

    n1 = {token for token in completion.split() if token in operators}
    n2, operands_list = get_variable_operands(completion)
    N2 = len(operands_list)

    N = N1 + N2
    n = len(n1) + len(n2)

    if n == 0:  # Handling math domain error
        return {"Error": "Halstead Vocabulary (n) is zero. Cannot calculate log2."}

    V = N * math.log2(n)
    D = (len(n1) / 2) * (N2 / len(n2))
    E = D * V

    return {
        "Halstead Length (N)": N,
        "Halstead Vocabulary (n)": n,
        "Halstead Volume (V)": V,
        "Halstead Difficulty (D)": D,
        "Halstead Effort (E)": E,
    }

# Function to calculate average Halstead metrics
def calculate_avg_metrics(halstead_metrics_list):
    avg_metrics = {}

    # Collect all metrics for calculation
    metric_keys = [key for key in halstead_metrics_list[0].keys() if key != "Error"]

    for key in metric_keys:
        valid_metrics = [metrics[key] for metrics in halstead_metrics_list if key in metrics]
        if valid_metrics:
            total = sum(valid_metrics)
            avg_metrics[key] = total / len(valid_metrics)

    return avg_metrics

# Main execution block
if __name__ == "__main__":
    jsonl_file = "/content/data_gpt-3.5-turbo-1106.jsonl"

    loc_counts = count_loc(jsonl_file)
    halstead_metrics_list = []

    for task_id, loc_count in loc_counts.items():
        print(f"Task ID: {task_id}, LOC: {loc_count}")

        with open(jsonl_file, 'r') as f:
            for line in f:
                data = json.loads(line.strip())
                if data.get('task_id') == task_id:
                    completion = data.get('completion')

                    if completion:
                        try:
                            halstead_metrics = calculate_halstead_metrics(completion)

                            if "Error" in halstead_metrics:
                                print(f"Error calculating Halstead metrics for Task ID {task_id}: {halstead_metrics['Error']}")
                            else:
                                halstead_metrics_list.append(halstead_metrics)

                                print("Halstead Metrics:")
                                for metric, value in halstead_metrics.items():
                                    print(f"{metric}: {value}")
                        except Exception as e:
                            print(f"An error occurred while calculating Halstead metrics for Task ID {task_id}: {e}")
                    break
        print()

    # Calculate the average Halstead metrics
    if halstead_metrics_list:
        avg_metrics = calculate_avg_metrics(halstead_metrics_list)

        print("Average Halstead Metrics:")
        for metric, value in avg_metrics.items():
            print(f"{metric}: {value}")
    else:
        print("No valid Halstead metrics were calculated.")
# Out:
# Task ID: HumanEval/0, LOC: 6
# Halstead Metrics:
# Halstead Length (N): 23
# Halstead Vocabulary (n): 13
# Halstead Volume (V): 85.11011351724513
# Halstead Difficulty (D): 2.8499999999999996
# Halstead Effort (E): 242.56382352414857
#
# Task ID: HumanEval/1, LOC: 15
# Halstead Metrics:
# Halstead Length (N): 33
# Halstead Vocabulary (n): 12
# Halstead Volume (V): 118.30376252379816
# Halstead Difficulty (D): 7.5
# Halstead Effort (E): 887.2782189284861
#
# Task ID: HumanEval/2, LOC: 10
# Halstead Metrics:
# Halstead Length (N): 8
# Halstead Vocabulary (n): 5
# Halstead Volume (V): 18.575424759098897
# Halstead Difficulty (D): 1.6666666666666667
# Halstead Effort (E): 30.95904126516483
#
# Task ID: HumanEval/3, LOC: 7
# Halstead Metrics:
# Halstead Length (N): 13
# Halstead Vocabulary (n): 10
# Halstead Volume (V): 43.18506523353571
# Halstead Difficulty (D): 3.0
# Halstead Effort (E): 129.55519570060713
#
# Task ID: HumanEval/4, LOC: 6
# Halstead Metrics:
# Halstead Length (N): 24
# Halstead Vocabulary (n): 13
# Halstead Volume (V): 88.81055323538621
# Halstead Difficulty (D): 4.0
# Halstead Effort (E): 355.24221294154484
#
# Task ID: HumanEval/5, LOC: 7
# Halstead Metrics:
# Halstead Length (N): 16
# Halstead Vocabulary (n): 8
# Halstead Volume (V): 48.0
# Halstead Difficulty (D): 2.3333333333333335
# Halstead Effort (E): 112.0
#
# Task ID: HumanEval/6, LOC: 16
# Halstead Metrics:
# Halstead Length (N): 36
# Halstead Vocabulary (n): 14
# Halstead Volume (V): 137.06477719407374
# Halstead Difficulty (D): 6.666666666666666
# Halstead Effort (E): 913.7651812938249
#
# Task ID: HumanEval/7, LOC: 2
# Halstead Metrics:
# Halstead Length (N): 12
# Halstead Vocabulary (n): 6
# Halstead Volume (V): 31.019550008653873
# Halstead Difficulty (D): 1.0
# Halstead Effort (E): 31.019550008653873
#
# Task ID: HumanEval/8, LOC: 11
# Halstead Metrics:
# Halstead Length (N): 21
# Halstead Vocabulary (n): 12
# Halstead Volume (V): 75.28421251514428
# Halstead Difficulty (D): 4.0
# Halstead Effort (E): 301.1368500605771
#
# Task ID: HumanEval/9, LOC: 7
# Halstead Metrics:
# Halstead Length (N): 20
# Halstead Vocabulary (n): 10
# Halstead Volume (V): 66.43856189774725
# Halstead Difficulty (D): 2.0
# Halstead Effort (E): 132.8771237954945
#
# Task ID: HumanEval/10, LOC: 24
# Halstead Metrics:
# Halstead Length (N): 29
# Halstead Vocabulary (n): 14
# Halstead Volume (V): 110.41329273967052
# Halstead Difficulty (D): 5.833333333333334
# Halstead Effort (E): 644.0775409814114
#
# Task ID: HumanEval/11, LOC: 8
# Halstead Metrics:
# Halstead Length (N): 20
# Halstead Vocabulary (n): 11
# Halstead Volume (V): 69.18863237274594
# Halstead Difficulty (D): 4.285714285714286
# Halstead Effort (E): 296.52271016891115
#
# Task ID: HumanEval/12, LOC: 6
# Halstead Metrics:
# Halstead Length (N): 25
# Halstead Vocabulary (n): 13
# Halstead Volume (V): 92.5109929535273
# Halstead Difficulty (D): 4.222222222222222
# Halstead Effort (E): 390.6019702482264
#
# Task ID: HumanEval/13, LOC: 10
# Halstead Metrics:
# Halstead Length (N): 13
# Halstead Vocabulary (n): 6
# Halstead Volume (V): 33.60451250937503
# Halstead Difficulty (D): 5.0
# Halstead Effort (E): 168.02256254687512
#
# Task ID: HumanEval/14, LOC: 7
# Halstead Metrics:
# Halstead Length (N): 13
# Halstead Vocabulary (n): 9
# Halstead Volume (V): 41.209025018750054
# Halstead Difficulty (D): 1.5714285714285714
# Halstead Effort (E): 64.75703931517866
#
# Task ID: HumanEval/15, LOC: 2
# Halstead Metrics:
# Halstead Length (N): 8
# Halstead Vocabulary (n): 6
# Halstead Volume (V): 20.67970000576925
# Halstead Difficulty (D): 0.7
# Halstead Effort (E): 14.475790004038473
#
# Task ID: HumanEval/16, LOC: 10
# Halstead Metrics:
# Halstead Length (N): 11
# Halstead Vocabulary (n): 7
# Halstead Volume (V): 30.880904142633646
# Halstead Difficulty (D): 0.75
# Halstead Effort (E): 23.160678106975233
#
# Task ID: HumanEval/17, LOC: 8
# Halstead Metrics:
# Halstead Length (N): 13
# Halstead Vocabulary (n): 9
# Halstead Volume (V): 41.209025018750054
# Halstead Difficulty (D): 1.4285714285714286
# Halstead Effort (E): 58.870035741071504
#
# Task ID: HumanEval/18, LOC: 10
# Halstead Metrics:
# Halstead Length (N): 23
# Halstead Vocabulary (n): 11
# Halstead Volume (V): 79.56692722865783
# Halstead Difficulty (D): 4.571428571428571
# Halstead Effort (E): 363.7345244738644
#
# Task ID: HumanEval/19, LOC: 16
# Halstead Metrics:
# Halstead Length (N): 11
# Halstead Vocabulary (n): 6
# Halstead Volume (V): 28.43458750793272
# Halstead Difficulty (D): 0.9
# Halstead Effort (E): 25.591128757139447
#
# Task ID: HumanEval/20, LOC: 10
# Halstead Metrics:
# Halstead Length (N): 38
# Halstead Vocabulary (n): 15
# Halstead Volume (V): 148.46184263312372
# Halstead Difficulty (D): 5.2727272727272725
# Halstead Effort (E): 782.798806611016
#
# Task ID: HumanEval/21, LOC: 7
# Halstead Metrics:
# Halstead Length (N): 25
# Halstead Vocabulary (n): 13
# Halstead Volume (V): 92.5109929535273
# Halstead Difficulty (D): 4.0
# Halstead Effort (E): 370.0439718141092
#
# Task ID: HumanEval/22, LOC: 8
# Halstead Metrics:
# Halstead Length (N): 11
# Halstead Vocabulary (n): 7
# Halstead Volume (V): 30.880904142633646
# Halstead Difficulty (D): 0.8333333333333334
# Halstead Effort (E): 25.73408678552804
#
# Task ID: HumanEval/23, LOC: 8
# Halstead Metrics:
# Halstead Length (N): 4
# Halstead Vocabulary (n): 4
# Halstead Volume (V): 8.0
# Halstead Difficulty (D): 0.0
# Halstead Effort (E): 0.0
#
# Task ID: HumanEval/24, LOC: 8
# Halstead Metrics:
# Halstead Length (N): 11
# Halstead Vocabulary (n): 7
# Halstead Volume (V): 30.880904142633646
# Halstead Difficulty (D): 3.0
# Halstead Effort (E): 92.64271242790093
#
# Task ID: HumanEval/25, LOC: 9
# Halstead Metrics:
# Halstead Length (N): 21
# Halstead Vocabulary (n): 11
# Halstead Volume (V): 72.64806399138324
# Halstead Difficulty (D): 8.399999999999999
# Halstead Effort (E): 610.2437375276191
#
# Task ID: HumanEval/26, LOC: 6
# Halstead Metrics:
# Halstead Length (N): 15
# Halstead Vocabulary (n): 8
# Halstead Volume (V): 45.0
# Halstead Difficulty (D): 3.5999999999999996
# Halstead Effort (E): 161.99999999999997
#
# Task ID: HumanEval/27, LOC: 6
# Halstead Metrics:
# Halstead Length (N): 4
# Halstead Vocabulary (n): 3
# Halstead Volume (V): 6.339850002884624
# Halstead Difficulty (D): 0.75
# Halstead Effort (E): 4.754887502163468
#
# Task ID: HumanEval/28, LOC: 8
# Halstead Metrics:
# Halstead Length (N): 4
# Halstead Vocabulary (n): 3
# Halstead Volume (V): 6.339850002884624
# Halstead Difficulty (D): 0.0
# Halstead Effort (E): 0.0
#
# Task ID: HumanEval/29, LOC: 2
# Halstead Metrics:
# Halstead Length (N): 11
# Halstead Vocabulary (n): 6
# Halstead Volume (V): 28.43458750793272
# Halstead Difficulty (D): 1.0
# Halstead Effort (E): 28.43458750793272
#
# Task ID: HumanEval/30, LOC: 8
# Halstead Metrics:
# Halstead Length (N): 8
# Halstead Vocabulary (n): 5
# Halstead Volume (V): 18.575424759098897
# Halstead Difficulty (D): 1.6666666666666667
# Halstead Effort (E): 30.95904126516483
#
# Task ID: HumanEval/31, LOC: 8
# Halstead Metrics:
# Halstead Length (N): 15
# Halstead Vocabulary (n): 12
# Halstead Volume (V): 53.77443751081734
# Halstead Difficulty (D): 7.0
# Halstead Effort (E): 376.4210625757214
#
# Task ID: HumanEval/32, LOC: 22
# Halstead Metrics:
# Halstead Length (N): 32
# Halstead Vocabulary (n): 15
# Halstead Volume (V): 125.0204990594726
# Halstead Difficulty (D): 8.0
# Halstead Effort (E): 1000.1639924757808
#
# Task ID: HumanEval/33, LOC: 6
# Halstead Metrics:
# Halstead Length (N): 19
# Halstead Vocabulary (n): 11
# Halstead Volume (V): 65.72920075410865
# Halstead Difficulty (D): 4.0
# Halstead Effort (E): 262.9168030164346
#
# Task ID: HumanEval/34, LOC: 6
# Halstead Metrics:
# Halstead Length (N): 6
# Halstead Vocabulary (n): 5
# Halstead Volume (V): 13.931568569324174
# Halstead Difficulty (D): 0.625
# Halstead Effort (E): 8.707230355827608
#
# Task ID: HumanEval/35, LOC: 8
# Halstead Metrics:
# Halstead Length (N): 4
# Halstead Vocabulary (n): 4
# Halstead Volume (V): 8.0
# Halstead Difficulty (D): 0.5
# Halstead Effort (E): 4.0
#
# Task ID: HumanEval/36, LOC: 6
# Halstead Metrics:
# Halstead Length (N): 21
# Halstead Vocabulary (n): 13
# Halstead Volume (V): 77.70923408096293
# Halstead Difficulty (D): 6.416666666666666
# Halstead Effort (E): 498.6342520195121
#
# Task ID: HumanEval/37, LOC: 5
# Halstead Metrics:
# Halstead Length (N): 32
# Halstead Vocabulary (n): 13
# Halstead Volume (V): 118.41407098051495
# Halstead Difficulty (D): 5.111111111111111
# Halstead Effort (E): 605.2274739004097
#
# Task ID: HumanEval/38, LOC: 7
# Halstead Metrics:
# Halstead Length (N): 32
# Halstead Vocabulary (n): 14
# Halstead Volume (V): 121.83535750584333
# Halstead Difficulty (D): 7.875
# Halstead Effort (E): 959.4534403585162
#
# Task ID: HumanEval/39, LOC: 27
# Halstead Metrics:
# Halstead Length (N): 50
# Halstead Vocabulary (n): 21
# Halstead Volume (V): 219.61587113893805
# Halstead Difficulty (D): 14.545454545454547
# Halstead Effort (E): 3194.4126711118265
#
# Task ID: HumanEval/40, LOC: 23
# Halstead Metrics:
# Halstead Length (N): 29
# Halstead Vocabulary (n): 11
# Halstead Volume (V): 100.32351694048162
# Halstead Difficulty (D): 6.0
# Halstead Effort (E): 601.9411016428897
#
# Task ID: HumanEval/41, LOC: 13
# Halstead Metrics:
# Halstead Length (N): 10
# Halstead Vocabulary (n): 8
# Halstead Volume (V): 30.0
# Halstead Difficulty (D): 4.5
# Halstead Effort (E): 135.0
#
# Task ID: HumanEval/42, LOC: 8
# Halstead Metrics:
# Halstead Length (N): 6
# Halstead Vocabulary (n): 5
# Halstead Volume (V): 13.931568569324174
# Halstead Difficulty (D): 1.3333333333333333
# Halstead Effort (E): 18.575424759098897
#
# Task ID: HumanEval/43, LOC: 21
# Halstead Metrics:
# Halstead Length (N): 19
# Halstead Vocabulary (n): 9
# Halstead Volume (V): 60.228575027403934
# Halstead Difficulty (D): 5.2
# Halstead Effort (E): 313.18859014250046
#
# Task ID: HumanEval/44, LOC: 19
# Halstead Metrics:
# Halstead Length (N): 31
# Halstead Vocabulary (n): 13
# Halstead Volume (V): 114.71363126237385
# Halstead Difficulty (D): 10.5
# Halstead Effort (E): 1204.4931282549255
#
# Task ID: HumanEval/45, LOC: 6
# Halstead Metrics:
# Halstead Length (N): 5
# Halstead Vocabulary (n): 4
# Halstead Volume (V): 10.0
# Halstead Difficulty (D): 1.0
# Halstead Effort (E): 10.0
#
# Task ID: HumanEval/46, LOC: 14
# Halstead Metrics:
# Halstead Length (N): 35
# Halstead Vocabulary (n): 12
# Halstead Volume (V): 125.47368752524046
# Halstead Difficulty (D): 6.0
# Halstead Effort (E): 752.8421251514428
#
# Task ID: HumanEval/47, LOC: 13
# Halstead Metrics:
# Halstead Length (N): 22
# Halstead Vocabulary (n): 13
# Halstead Volume (V): 81.40967379910403
# Halstead Difficulty (D): 8.166666666666668
# Halstead Effort (E): 664.8456693593497
#
# Task ID: HumanEval/48, LOC: 13
# Halstead Metrics:
# Halstead Length (N): 5
# Halstead Vocabulary (n): 4
# Halstead Volume (V): 10.0
# Halstead Difficulty (D): 1.5
# Halstead Effort (E): 15.0
#
# Task ID: HumanEval/49, LOC: 4
# Halstead Metrics:
# Halstead Length (N): 5
# Halstead Vocabulary (n): 4
# Halstead Volume (V): 10.0
# Halstead Difficulty (D): 0.0
# Halstead Effort (E): 0.0
#
# Task ID: HumanEval/50, LOC: 5
# Halstead Metrics:
# Halstead Length (N): 13
# Halstead Vocabulary (n): 9
# Halstead Volume (V): 41.209025018750054
# Halstead Difficulty (D): 3.2
# Halstead Effort (E): 131.86888006000018
#
# Task ID: HumanEval/51, LOC: 3
# Halstead Metrics:
# Halstead Length (N): 10
# Halstead Vocabulary (n): 6
# Halstead Volume (V): 25.84962500721156
# Halstead Difficulty (D): 3.0
# Halstead Effort (E): 77.54887502163469
#
# Task ID: HumanEval/52, LOC: 8
# Halstead Metrics:
# Halstead Length (N): 10
# Halstead Vocabulary (n): 8
# Halstead Volume (V): 30.0
# Halstead Difficulty (D): 1.1666666666666667
# Halstead Effort (E): 35.0
#
# Task ID: HumanEval/53, LOC: 8
# Halstead Metrics:
# Halstead Length (N): 6
# Halstead Vocabulary (n): 5
# Halstead Volume (V): 13.931568569324174
# Halstead Difficulty (D): 1.3333333333333333
# Halstead Effort (E): 18.575424759098897
#
# Task ID: HumanEval/54, LOC: 2
# Halstead Metrics:
# Halstead Length (N): 7
# Halstead Vocabulary (n): 5
# Halstead Volume (V): 16.253496664211536
# Halstead Difficulty (D): 0.75
# Halstead Effort (E): 12.190122498158651
#
# Task ID: HumanEval/55, LOC: 10
# Halstead Metrics:
# Halstead Length (N): 20
# Halstead Vocabulary (n): 11
# Halstead Volume (V): 69.18863237274594
# Halstead Difficulty (D): 5.833333333333334
# Halstead Effort (E): 403.6003555076847
#
# Task ID: HumanEval/56, LOC: 10
# Halstead Metrics:
# Halstead Length (N): 17
# Halstead Vocabulary (n): 8
# Halstead Volume (V): 51.0
# Halstead Difficulty (D): 5.5
# Halstead Effort (E): 280.5
#
# Task ID: HumanEval/57, LOC: 10
# Halstead Metrics:
# Halstead Length (N): 30
# Halstead Vocabulary (n): 13
# Halstead Volume (V): 111.01319154423277
# Halstead Difficulty (D): 11.083333333333332
# Halstead Effort (E): 1230.396206281913
#
# Task ID: HumanEval/58, LOC: 8
# Halstead Metrics:
# Halstead Length (N): 9
# Halstead Vocabulary (n): 6
# Halstead Volume (V): 23.264662506490403
# Halstead Difficulty (D): 0.8
# Halstead Effort (E): 18.611730005192324
#
# Task ID: HumanEval/59, LOC: 22
# Halstead Metrics:
# Halstead Length (N): 34
# Halstead Vocabulary (n): 20
# Halstead Volume (V): 146.94555522617034
# Halstead Difficulty (D): 27.0
# Halstead Effort (E): 3967.529991106599
#
# Task ID: HumanEval/60, LOC: 15
# Halstead Metrics:
# Halstead Length (N): 7
# Halstead Vocabulary (n): 6
# Halstead Volume (V): 18.094737505048094
# Halstead Difficulty (D): 3.0
# Halstead Effort (E): 54.28421251514428
#
# Task ID: HumanEval/61, LOC: 10
# Halstead Metrics:
# Halstead Length (N): 17
# Halstead Vocabulary (n): 8
# Halstead Volume (V): 51.0
# Halstead Difficulty (D): 5.5
# Halstead Effort (E): 280.5
#
# Task ID: HumanEval/62, LOC: 10
# Halstead Metrics:
# Halstead Length (N): 16
# Halstead Vocabulary (n): 8
# Halstead Volume (V): 48.0
# Halstead Difficulty (D): 2.4000000000000004
# Halstead Effort (E): 115.20000000000002
#
# Task ID: HumanEval/63, LOC: 12
# Halstead Metrics:
# Halstead Length (N): 27
# Halstead Vocabulary (n): 11
# Halstead Volume (V): 93.40465370320703
# Halstead Difficulty (D): 5.428571428571429
# Halstead Effort (E): 507.0538343888382
#
# Task ID: HumanEval/64, LOC: 16
# Halstead Metrics:
# Halstead Length (N): 38
# Halstead Vocabulary (n): 14
# Halstead Volume (V): 144.67948703818897
# Halstead Difficulty (D): 11.5
# Halstead Effort (E): 1663.8141009391732
#
# Task ID: HumanEval/65, LOC: 8
# Halstead Metrics:
# Halstead Length (N): 21
# Halstead Vocabulary (n): 10
# Halstead Volume (V): 69.7604899926346
# Halstead Difficulty (D): 5.0
# Halstead Effort (E): 348.802449963173
#
# Task ID: HumanEval/66, LOC: 6
# Halstead Metrics:
# Halstead Length (N): 11
# Halstead Vocabulary (n): 7
# Halstead Volume (V): 30.880904142633646
# Halstead Difficulty (D): 3.0
# Halstead Effort (E): 92.64271242790093
#
# Task ID: HumanEval/67, LOC: 9
# Halstead Metrics:
# Halstead Length (N): 18
# Halstead Vocabulary (n): 10
# Halstead Volume (V): 59.79470570797252
# Halstead Difficulty (D): 3.6666666666666665
# Halstead Effort (E): 219.2472542625659
#
# Task ID: HumanEval/68, LOC: 8
# Halstead Metrics:
# Halstead Length (N): 21
# Halstead Vocabulary (n): 11
# Halstead Volume (V): 72.64806399138324
# Halstead Difficulty (D): 5.833333333333334
# Halstead Effort (E): 423.7803732830689
#
# Task ID: HumanEval/69, LOC: 6
# Halstead Metrics:
# Halstead Length (N): 19
# Halstead Vocabulary (n): 10
# Halstead Volume (V): 63.11663380285988
# Halstead Difficulty (D): 6.5
# Halstead Effort (E): 410.2581197185892
#
# Task ID: HumanEval/70, LOC: 8
# Halstead Metrics:
# Halstead Length (N): 10
# Halstead Vocabulary (n): 3
# Halstead Volume (V): 15.84962500721156
# Halstead Difficulty (D): 2.25
# Halstead Effort (E): 35.66165626622601
#
# Task ID: HumanEval/71, LOC: 9
# Halstead Metrics:
# Halstead Length (N): 43
# Halstead Vocabulary (n): 14
# Halstead Volume (V): 163.71626164847697
# Halstead Difficulty (D): 12.0
# Halstead Effort (E): 1964.5951397817237
#
# Task ID: HumanEval/72, LOC: 5
# Halstead Metrics:
# Halstead Length (N): 8
# Halstead Vocabulary (n): 6
# Halstead Volume (V): 20.67970000576925
# Halstead Difficulty (D): 2.5
# Halstead Effort (E): 51.69925001442312
#
# Task ID: HumanEval/73, LOC: 7
# Halstead Metrics:
# Halstead Length (N): 22
# Halstead Vocabulary (n): 12
# Halstead Volume (V): 78.86917501586544
# Halstead Difficulty (D): 7.0
# Halstead Effort (E): 552.084225111058
#
# Task ID: HumanEval/74, LOC: 10
# Halstead Metrics:
# Halstead Length (N): 25
# Halstead Vocabulary (n): 10
# Halstead Volume (V): 83.04820237218405
# Halstead Difficulty (D): 4.071428571428571
# Halstead Effort (E): 338.1248239438922
#
# Task ID: HumanEval/75, LOC: 8
# Halstead Metrics:
# Halstead Length (N): 18
# Halstead Vocabulary (n): 9
# Halstead Volume (V): 57.05865002596162
# Halstead Difficulty (D): 4.4
# Halstead Effort (E): 251.05806011423115
#
# Task ID: HumanEval/76, LOC: 9
# Halstead Metrics:
# Halstead Length (N): 18
# Halstead Vocabulary (n): 8
# Halstead Volume (V): 54.0
# Halstead Difficulty (D): 8.333333333333334
# Halstead Effort (E): 450.00000000000006
#
# Task ID: HumanEval/77, LOC: 14
# Halstead Metrics:
# Halstead Length (N): 12
# Halstead Vocabulary (n): 7
# Halstead Volume (V): 33.68825906469125
# Halstead Difficulty (D): 5.0
# Halstead Effort (E): 168.44129532345625
#
# Task ID: HumanEval/78, LOC: 7
# Halstead Metrics:
# Halstead Length (N): 13
# Halstead Vocabulary (n): 7
# Halstead Volume (V): 36.49561398674886
# Halstead Difficulty (D): 3.0
# Halstead Effort (E): 109.48684196024658
#
# Task ID: HumanEval/79, LOC: 3
# Halstead Metrics:
# Halstead Length (N): 7
# Halstead Vocabulary (n): 5
# Halstead Volume (V): 16.253496664211536
# Halstead Difficulty (D): 1.3333333333333333
# Halstead Effort (E): 21.67132888561538
#
# Task ID: HumanEval/80, LOC: 7
# Halstead Metrics:
# Halstead Length (N): 26
# Halstead Vocabulary (n): 9
# Halstead Volume (V): 82.41805003750011
# Halstead Difficulty (D): 11.25
# Halstead Effort (E): 927.2030629218763
#
# Task ID: HumanEval/81, LOC: 30
# Halstead Metrics:
# Halstead Length (N): 43
# Halstead Vocabulary (n): 7
# Halstead Volume (V): 120.71626164847697
# Halstead Difficulty (D): 19.333333333333332
# Halstead Effort (E): 2333.847725203888
#
# Task ID: HumanEval/82, LOC: 11
# Halstead Metrics:
# Halstead Length (N): 19
# Halstead Vocabulary (n): 15
# Halstead Volume (V): 74.23092131656186
# Halstead Difficulty (D): 5.25
# Halstead Effort (E): 389.71233691194976
#
# Task ID: HumanEval/83, LOC: 7
# Halstead Metrics:
# Halstead Length (N): 14
# Halstead Vocabulary (n): 7
# Halstead Volume (V): 39.302968908806456
# Halstead Difficulty (D): 7.5
# Halstead Effort (E): 294.77226681604844
#
# Task ID: HumanEval/84, LOC: 3
# Halstead Metrics:
# Halstead Length (N): 11
# Halstead Vocabulary (n): 8
# Halstead Volume (V): 33.0
# Halstead Difficulty (D): 1.5
# Halstead Effort (E): 49.5
#
# Task ID: HumanEval/85, LOC: 11
# Halstead Metrics:
# Halstead Length (N): 16
# Halstead Vocabulary (n): 10
# Halstead Volume (V): 53.150849518197795
# Halstead Difficulty (D): 5.5
# Halstead Effort (E): 292.3296723500879
#
# Task ID: HumanEval/86, LOC: 4
# Halstead Metrics:
# Halstead Length (N): 11
# Halstead Vocabulary (n): 7
# Halstead Volume (V): 30.880904142633646
# Halstead Difficulty (D): 1.6
# Halstead Effort (E): 49.409446628213836
#
# Task ID: HumanEval/87, LOC: 8
# Halstead Metrics:
# Halstead Length (N): 32
# Halstead Vocabulary (n): 12
# Halstead Volume (V): 114.718800023077
# Halstead Difficulty (D): 4.333333333333333
# Halstead Effort (E): 497.11480010000025
#
# Task ID: HumanEval/88, LOC: 8
# Halstead Metrics:
# Halstead Length (N): 14
# Halstead Vocabulary (n): 8
# Halstead Volume (V): 42.0
# Halstead Difficulty (D): 7.5
# Halstead Effort (E): 315.0
#
# Task ID: HumanEval/89, LOC: 12
# Halstead Metrics:
# Halstead Length (N): 31
# Halstead Vocabulary (n): 13
# Halstead Volume (V): 114.71363126237385
# Halstead Difficulty (D): 9.916666666666668
# Halstead Effort (E): 1137.5768433518742
#
# Task ID: HumanEval/90, LOC: 9
# Halstead Metrics:
# Halstead Length (N): 12
# Halstead Vocabulary (n): 7
# Halstead Volume (V): 33.68825906469125
# Halstead Difficulty (D): 1.8
# Halstead Effort (E): 60.63886631644426
#
# Task ID: HumanEval/91, LOC: 9
# Halstead Metrics:
# Halstead Length (N): 18
# Halstead Vocabulary (n): 7
# Halstead Volume (V): 50.53238859703688
# Halstead Difficulty (D): 4.5
# Halstead Effort (E): 227.39574868666594
#
# Task ID: HumanEval/92, LOC: 8
# Halstead Metrics:
# Halstead Length (N): 28
# Halstead Vocabulary (n): 9
# Halstead Volume (V): 88.75790004038474
# Halstead Difficulty (D): 7.2
# Halstead Effort (E): 639.0568802907701
#
# Task ID: HumanEval/93, LOC: 12
# Halstead Metrics:
# Halstead Length (N): 35
# Halstead Vocabulary (n): 12
# Halstead Volume (V): 125.47368752524046
# Halstead Difficulty (D): 10.0
# Halstead Effort (E): 1254.7368752524046
#
# Task ID: HumanEval/94, LOC: 18
# Halstead Metrics:
# Halstead Length (N): 36
# Halstead Vocabulary (n): 21
# Halstead Volume (V): 158.12342722003538
# Halstead Difficulty (D): 9.0
# Halstead Effort (E): 1423.1108449803185
#
# Task ID: HumanEval/95, LOC: 8
# Halstead Metrics:
# Halstead Length (N): 18
# Halstead Vocabulary (n): 10
# Halstead Volume (V): 59.79470570797252
# Halstead Difficulty (D): 4.333333333333333
# Halstead Effort (E): 259.1103914012142
#
# Task ID: HumanEval/96, LOC: 11
# Halstead Metrics:
# Halstead Length (N): 23
# Halstead Vocabulary (n): 14
# Halstead Volume (V): 87.56916320732489
# Halstead Difficulty (D): 7.5
# Halstead Effort (E): 656.7687240549367
#
# Task ID: HumanEval/97, LOC: 2
# Halstead Metrics:
# Halstead Length (N): 6
# Halstead Vocabulary (n): 5
# Halstead Volume (V): 13.931568569324174
# Halstead Difficulty (D): 1.0
# Halstead Effort (E): 13.931568569324174
#
# Task ID: HumanEval/98, LOC: 7
# Halstead Metrics:
# Halstead Length (N): 19
# Halstead Vocabulary (n): 10
# Halstead Volume (V): 63.11663380285988
# Halstead Difficulty (D): 4.333333333333333
# Halstead Effort (E): 273.50541314572615
#
# Task ID: HumanEval/99, LOC: 6
# Halstead Metrics:
# Halstead Length (N): 12
# Halstead Vocabulary (n): 8
# Halstead Volume (V): 36.0
# Halstead Difficulty (D): 4.0
# Halstead Effort (E): 144.0
#
# Task ID: HumanEval/100, LOC: 8
# Halstead Metrics:
# Halstead Length (N): 20
# Halstead Vocabulary (n): 9
# Halstead Volume (V): 63.39850002884624
# Halstead Difficulty (D): 8.125
# Halstead Effort (E): 515.1128127343758
#
# Task ID: HumanEval/101, LOC: 3
# Halstead Metrics:
# Halstead Length (N): 7
# Halstead Vocabulary (n): 5
# Halstead Volume (V): 16.253496664211536
# Halstead Difficulty (D): 1.6666666666666667
# Halstead Effort (E): 27.089161107019226
#
# Task ID: HumanEval/102, LOC: 6
# Halstead Metrics:
# Halstead Length (N): 18
# Halstead Vocabulary (n): 11
# Halstead Volume (V): 62.26976913547135
# Halstead Difficulty (D): 6.6000000000000005
# Halstead Effort (E): 410.98047629411093
#
# Task ID: HumanEval/103, LOC: 5
# Halstead Metrics:
# Halstead Length (N): 16
# Halstead Vocabulary (n): 9
# Halstead Volume (V): 50.718800023076994
# Halstead Difficulty (D): 5.625
# Halstead Effort (E): 285.2932501298081
#
# Task ID: HumanEval/104, LOC: 6
# Halstead Metrics:
# Halstead Length (N): 18
# Halstead Vocabulary (n): 12
# Halstead Volume (V): 64.5293250129808
# Halstead Difficulty (D): 3.25
# Halstead Effort (E): 209.72030629218762
#
# Task ID: HumanEval/105, LOC: 7
# Halstead Metrics:
# Halstead Length (N): 26
# Halstead Vocabulary (n): 11
# Halstead Volume (V): 89.94522208456974
# Halstead Difficulty (D): 3.1875
# Halstead Effort (E): 286.70039539456604
#
# Task ID: HumanEval/106, LOC: 11
# Halstead Metrics:
# Halstead Length (N): 25
# Halstead Vocabulary (n): 12
# Halstead Volume (V): 89.62406251802891
# Halstead Difficulty (D): 6.428571428571429
# Halstead Effort (E): 576.1546876159001
#
# Task ID: HumanEval/107, LOC: 10
# Halstead Metrics:
# Halstead Length (N): 22
# Halstead Vocabulary (n): 11
# Halstead Volume (V): 76.10749561002054
# Halstead Difficulty (D): 5.833333333333334
# Halstead Effort (E): 443.9603910584532
#
# Task ID: HumanEval/108, LOC: 9
# Halstead Metrics:
# Halstead Length (N): 24
# Halstead Vocabulary (n): 13
# Halstead Volume (V): 88.81055323538621
# Halstead Difficulty (D): 5.0
# Halstead Effort (E): 444.0527661769311
#
# Task ID: HumanEval/109, LOC: 10
# Halstead Metrics:
# Halstead Length (N): 22
# Halstead Vocabulary (n): 12
# Halstead Volume (V): 78.86917501586544
# Halstead Difficulty (D): 5.357142857142857
# Halstead Effort (E): 422.51343758499337
#
# Task ID: HumanEval/110, LOC: 9
# Halstead Metrics:
# Halstead Length (N): 17
# Halstead Vocabulary (n): 13
# Halstead Volume (V): 62.907475208398566
# Halstead Difficulty (D): 4.666666666666666
# Halstead Effort (E): 293.5682176391933
#
# Task ID: HumanEval/111, LOC: 9
# Halstead Metrics:
# Halstead Length (N): 34
# Halstead Vocabulary (n): 12
# Halstead Volume (V): 121.8887250245193
# Halstead Difficulty (D): 6.0
# Halstead Effort (E): 731.3323501471158
#
# Task ID: HumanEval/112, LOC: 3
# Halstead Metrics:
# Halstead Length (N): 14
# Halstead Vocabulary (n): 8
# Halstead Volume (V): 42.0
# Halstead Difficulty (D): 4.5
# Halstead Effort (E): 189.0
#
# Task ID: HumanEval/113, LOC: 6
# Halstead Metrics:
# Halstead Length (N): 21
# Halstead Vocabulary (n): 11
# Halstead Volume (V): 72.64806399138324
# Halstead Difficulty (D): 4.285714285714286
# Halstead Effort (E): 311.34884567735673
#
# Task ID: HumanEval/114, LOC: 7
# Halstead Metrics:
# Halstead Length (N): 21
# Halstead Vocabulary (n): 9
# Halstead Volume (V): 66.56842503028855
# Halstead Difficulty (D): 3.75
# Halstead Effort (E): 249.63159386358205
#
# Task ID: HumanEval/115, LOC: 5
# Halstead Metrics:
# Halstead Length (N): 13
# Halstead Vocabulary (n): 10
# Halstead Volume (V): 43.18506523353571
# Halstead Difficulty (D): 3.0
# Halstead Effort (E): 129.55519570060713
#
# Task ID: HumanEval/116, LOC: 2
# Halstead Metrics:
# Halstead Length (N): 5
# Halstead Vocabulary (n): 4
# Halstead Volume (V): 10.0
# Halstead Difficulty (D): 0.0
# Halstead Effort (E): 0.0
#
# Task ID: HumanEval/117, LOC: 8
# Halstead Metrics:
# Halstead Length (N): 23
# Halstead Vocabulary (n): 12
# Halstead Volume (V): 82.45413751658658
# Halstead Difficulty (D): 3.75
# Halstead Effort (E): 309.2030156871997
#
# Task ID: HumanEval/118, LOC: 7
# Halstead Metrics:
# Halstead Length (N): 26
# Halstead Vocabulary (n): 10
# Halstead Volume (V): 86.37013046707142
# Halstead Difficulty (D): 5.666666666666667
# Halstead Effort (E): 489.43073931340473
#
# Task ID: HumanEval/119, LOC: 15
# Halstead Metrics:
# Halstead Length (N): 18
# Halstead Vocabulary (n): 10
# Halstead Volume (V): 59.79470570797252
# Halstead Difficulty (D): 7.5
# Halstead Effort (E): 448.4602928097939
#
# Task ID: HumanEval/120, LOC: 3
# Halstead Metrics:
# Halstead Length (N): 3
# Halstead Vocabulary (n): 2
# Halstead Volume (V): 3.0
# Halstead Difficulty (D): 0.0
# Halstead Effort (E): 0.0
#
# Task ID: HumanEval/121, LOC: 2
# Halstead Metrics:
# Halstead Length (N): 16
# Halstead Vocabulary (n): 10
# Halstead Volume (V): 53.150849518197795
# Halstead Difficulty (D): 5.0
# Halstead Effort (E): 265.754247590989
#
# Task ID: HumanEval/122, LOC: 15
# Halstead Metrics:
# Halstead Length (N): 17
# Halstead Vocabulary (n): 9
# Halstead Volume (V): 53.8887250245193
# Halstead Difficulty (D): 3.75
# Halstead Effort (E): 202.08271884194738
#
# Task ID: HumanEval/123, LOC: 9
# Halstead Metrics:
# Halstead Length (N): 27
# Halstead Vocabulary (n): 12
# Halstead Volume (V): 96.79398751947122
# Halstead Difficulty (D): 15.0
# Halstead Effort (E): 1451.9098127920684
#
# Task ID: HumanEval/124, LOC: 22
# Halstead Metrics:
# Halstead Length (N): 57
# Halstead Vocabulary (n): 16
# Halstead Volume (V): 228.0
# Halstead Difficulty (D): 16.714285714285715
# Halstead Effort (E): 3810.857142857143
#
# Task ID: HumanEval/125, LOC: 8
# Halstead Metrics:
# Halstead Length (N): 19
# Halstead Vocabulary (n): 10
# Halstead Volume (V): 63.11663380285988
# Halstead Difficulty (D): 6.0
# Halstead Effort (E): 378.69980281715925
#
# Task ID: HumanEval/126, LOC: 7
# Halstead Metrics:
# Halstead Length (N): 17
# Halstead Vocabulary (n): 9
# Halstead Volume (V): 53.8887250245193
# Halstead Difficulty (D): 5.2
# Halstead Effort (E): 280.2213701275004
#
# Task ID: HumanEval/127, LOC: 20
# Halstead Metrics:
# Halstead Length (N): 41
# Halstead Vocabulary (n): 24
# Halstead Volume (V): 187.9834625295674
# Halstead Difficulty (D): 7.0
# Halstead Effort (E): 1315.8842377069718
#
# Task ID: HumanEval/128, LOC: 15
# Halstead Metrics:
# Halstead Length (N): 29
# Halstead Vocabulary (n): 13
# Halstead Volume (V): 107.31275182609167
# Halstead Difficulty (D): 13.6
# Halstead Effort (E): 1459.4534248348466
#
# Task ID: HumanEval/129, LOC: 24
# Halstead Metrics:
# Halstead Length (N): 95
# Halstead Vocabulary (n): 29
# Halstead Volume (V): 461.5081945371193
# Halstead Difficulty (D): 13.333333333333334
# Halstead Effort (E): 6153.4425938282575
#
# Task ID: HumanEval/130, LOC: 13
# Halstead Metrics:
# Halstead Length (N): 31
# Halstead Vocabulary (n): 11
# Halstead Volume (V): 107.24238017775622
# Halstead Difficulty (D): 14.875
# Halstead Effort (E): 1595.2304051441238
#
# Task ID: HumanEval/131, LOC: 11
# Halstead Metrics:
# Halstead Length (N): 19
# Halstead Vocabulary (n): 10
# Halstead Volume (V): 63.11663380285988
# Halstead Difficulty (D): 11.666666666666668
# Halstead Effort (E): 736.360727700032
#
# Task ID: HumanEval/132, LOC: 8
# Halstead Metrics:
# Halstead Length (N): 17
# Halstead Vocabulary (n): 9
# Halstead Volume (V): 53.8887250245193
# Halstead Difficulty (D): 6.875
# Halstead Effort (E): 370.4849845435702
#
# Task ID: HumanEval/133, LOC: 7
# Halstead Metrics:
# Halstead Length (N): 11
# Halstead Vocabulary (n): 8
# Halstead Volume (V): 33.0
# Halstead Difficulty (D): 3.5
# Halstead Effort (E): 115.5
#
# Task ID: HumanEval/134, LOC: 9
# Halstead Metrics:
# Halstead Length (N): 9
# Halstead Vocabulary (n): 5
# Halstead Volume (V): 20.89735285398626
# Halstead Difficulty (D): 3.75
# Halstead Effort (E): 78.36507320244847
#
# Task ID: HumanEval/135, LOC: 6
# Halstead Metrics:
# Halstead Length (N): 16
# Halstead Vocabulary (n): 8
# Halstead Volume (V): 48.0
# Halstead Difficulty (D): 3.5999999999999996
# Halstead Effort (E): 172.79999999999998
#
# Task ID: HumanEval/136, LOC: 15
# Halstead Metrics:
# Halstead Length (N): 32
# Halstead Vocabulary (n): 12
# Halstead Volume (V): 114.718800023077
# Halstead Difficulty (D): 5.5
# Halstead Effort (E): 630.9534001269235
#
# Task ID: HumanEval/137, LOC: 37
# Halstead Metrics:
# Halstead Length (N): 92
# Halstead Vocabulary (n): 9
# Halstead Volume (V): 291.63310013269273
# Halstead Difficulty (D): 18.0
# Halstead Effort (E): 5249.395802388469
#
# Task ID: HumanEval/138, LOC: 6
# Halstead Metrics:
# Halstead Length (N): 5
# Halstead Vocabulary (n): 4
# Halstead Volume (V): 10.0
# Halstead Difficulty (D): 3.0
# Halstead Effort (E): 30.0
#
# Task ID: HumanEval/139, LOC: 8
# Halstead Metrics:
# Halstead Length (N): 19
# Halstead Vocabulary (n): 9
# Halstead Volume (V): 60.228575027403934
# Halstead Difficulty (D): 3.25
# Halstead Effort (E): 195.7428688390628
#
# Task ID: HumanEval/140, LOC: 5
# Halstead Metrics:
# Halstead Length (N): 9
# Halstead Vocabulary (n): 3
# Halstead Volume (V): 14.264662506490405
# Halstead Difficulty (D): 6.0
# Halstead Effort (E): 85.58797503894243
#
# Task ID: HumanEval/141, LOC: 13
# Halstead Metrics:
# Halstead Length (N): 18
# Halstead Vocabulary (n): 11
# Halstead Volume (V): 62.26976913547135
# Halstead Difficulty (D): 6.0
# Halstead Effort (E): 373.6186148128281
#
# Task ID: HumanEval/142, LOC: 8
# Halstead Metrics:
# Halstead Length (N): 24
# Halstead Vocabulary (n): 11
# Halstead Volume (V): 83.02635884729514
# Halstead Difficulty (D): 8.399999999999999
# Halstead Effort (E): 697.4214143172791
#
# Task ID: HumanEval/143, LOC: 12
# Halstead Metrics:
# Halstead Length (N): 25
# Halstead Vocabulary (n): 16
# Halstead Volume (V): 100.0
# Halstead Difficulty (D): 5.1
# Halstead Effort (E): 509.99999999999994
#
# Task ID: HumanEval/144, LOC: 5
# Halstead Metrics:
# Halstead Length (N): 9
# Halstead Vocabulary (n): 7
# Halstead Volume (V): 25.26619429851844
# Halstead Difficulty (D): 2.25
# Halstead Effort (E): 56.848937171666485
#
# Task ID: HumanEval/145, LOC: 2
# Halstead Metrics:
# Halstead Length (N): 12
# Halstead Vocabulary (n): 9
# Halstead Volume (V): 38.039100017307746
# Halstead Difficulty (D): 0.6875
# Halstead Effort (E): 26.151881261899074
#
# Task ID: HumanEval/146, LOC: 6
# Halstead Metrics:
# Halstead Length (N): 18
# Halstead Vocabulary (n): 9
# Halstead Volume (V): 57.05865002596162
# Halstead Difficulty (D): 6.25
# Halstead Effort (E): 356.6165626622601
#
# Task ID: HumanEval/147, LOC: 11
# Halstead Metrics:
# Halstead Length (N): 50
# Halstead Vocabulary (n): 17
# Halstead Volume (V): 204.37314206251696
# Halstead Difficulty (D): 12.88888888888889
# Halstead Effort (E): 2634.142719916885
#
# Task ID: HumanEval/148, LOC: 11
# Halstead Metrics:
# Halstead Length (N): 30
# Halstead Vocabulary (n): 11
# Halstead Volume (V): 103.78294855911892
# Halstead Difficulty (D): 8.75
# Halstead Effort (E): 908.1007998922905
#
# Task ID: HumanEval/149, LOC: 4
# Halstead Metrics:
# Halstead Length (N): 15
# Halstead Vocabulary (n): 8
# Halstead Volume (V): 45.0
# Halstead Difficulty (D): 5.5
# Halstead Effort (E): 247.5
#
# Task ID: HumanEval/150, LOC: 13
# Halstead Metrics:
# Halstead Length (N): 17
# Halstead Vocabulary (n): 14
# Halstead Volume (V): 64.72503367497927
# Halstead Difficulty (D): 4.125
# Halstead Effort (E): 266.9907639092895
#
# Task ID: HumanEval/151, LOC: 2
# Halstead Metrics:
# Halstead Length (N): 11
# Halstead Vocabulary (n): 8
# Halstead Volume (V): 33.0
# Halstead Difficulty (D): 5.0
# Halstead Effort (E): 165.0
#
# Task ID: HumanEval/152, LOC: 2
# Halstead Metrics:
# Halstead Length (N): 16
# Halstead Vocabulary (n): 9
# Halstead Volume (V): 50.718800023076994
# Halstead Difficulty (D): 3.25
# Halstead Effort (E): 164.83610007500022
#
# Task ID: HumanEval/153, LOC: 9
# Halstead Metrics:
# Halstead Length (N): 35
# Halstead Vocabulary (n): 14
# Halstead Volume (V): 133.25742227201616
# Halstead Difficulty (D): 3.409090909090909
# Halstead Effort (E): 454.2866668364187
#
# Task ID: HumanEval/154, LOC: 6
# Halstead Metrics:
# Halstead Length (N): 13
# Halstead Vocabulary (n): 8
# Halstead Volume (V): 39.0
# Halstead Difficulty (D): 2.7
# Halstead Effort (E): 105.30000000000001
#
# Task ID: HumanEval/155, LOC: 13
# Halstead Metrics:
# Halstead Length (N): 26
# Halstead Vocabulary (n): 14
# Halstead Volume (V): 98.99122797349771
# Halstead Difficulty (D): 6.375
# Halstead Effort (E): 631.0690783310479
#
# Task ID: HumanEval/156, LOC: 24
# Halstead Metrics:
# Halstead Length (N): 32
# Halstead Vocabulary (n): 15
# Halstead Volume (V): 125.0204990594726
# Halstead Difficulty (D): 10.857142857142858
# Halstead Effort (E): 1357.3654183599883
#
# Task ID: HumanEval/157, LOC: 16
# Halstead Metrics:
# Halstead Length (N): 17
# Halstead Vocabulary (n): 10
# Halstead Volume (V): 56.47277761308516
# Halstead Difficulty (D): 6.0
# Halstead Effort (E): 338.83666567851094
#
# Task ID: HumanEval/158, LOC: 9
# Halstead Metrics:
# Halstead Length (N): 30
# Halstead Vocabulary (n): 14
# Halstead Volume (V): 114.22064766172812
# Halstead Difficulty (D): 9.5
# Halstead Effort (E): 1085.0961527864172
#
# Task ID: HumanEval/159, LOC: 4
# Halstead Metrics:
# Halstead Length (N): 15
# Halstead Vocabulary (n): 10
# Halstead Volume (V): 49.82892142331043
# Halstead Difficulty (D): 2.357142857142857
# Halstead Effort (E): 117.45388621208888
#
# Task ID: HumanEval/160, LOC: 5
# Halstead Metrics:
# Halstead Length (N): 21
# Halstead Vocabulary (n): 12
# Halstead Volume (V): 75.28421251514428
# Halstead Difficulty (D): 3.75
# Halstead Effort (E): 282.31579693179106
#
# Task ID: HumanEval/161, LOC: 15
# Halstead Metrics:
# Halstead Length (N): 26
# Halstead Vocabulary (n): 8
# Halstead Volume (V): 78.0
# Halstead Difficulty (D): 8.5
# Halstead Effort (E): 663.0
#
# Task ID: HumanEval/162, LOC: 7
# Halstead Metrics:
# Halstead Length (N): 3
# Halstead Vocabulary (n): 2
# Halstead Volume (V): 3.0
# Halstead Difficulty (D): 0.0
# Halstead Effort (E): 0.0
#
# Task ID: HumanEval/163, LOC: 3
# Halstead Metrics:
# Halstead Length (N): 16
# Halstead Vocabulary (n): 10
# Halstead Volume (V): 53.150849518197795
# Halstead Difficulty (D): 5.5
# Halstead Effort (E): 292.3296723500879
#
# Average Halstead Metrics:
# Halstead Length (N): 20.140243902439025
# Halstead Vocabulary (n): 9.798780487804878
# Halstead Volume (V): 69.61555312158066
# Halstead Difficulty (D): 5.285152263048605
# Halstead Effort (E): 527.3092095162317

# %%
import json
import random

def count_loc(jsonl_file):
    loc_count = {}

    with open(jsonl_file, 'r') as f:
        for line in f:
            data = json.loads(line.strip())
            task_id = data.get('task_id')
            completion = data.get('completion')

            if task_id not in loc_count:
                loc_count[task_id] = 0

            # Count lines of code if completion exists
            if completion:
                loc_count[task_id] += completion.count('\n') + 1

    return loc_count

jsonl_file = "/content/cleanedClaude_2.jsonl"
loc_counts = count_loc(jsonl_file)
for task_id, loc_count in loc_counts.items():
    print(f"Task ID: {task_id}, LOC: {loc_count}")

# Calculate the total LOC and the number of tasks
total_loc = sum(loc_counts.values())
num_tasks = len(loc_counts)

# Calculate the average LOC
average_loc = total_loc / num_tasks

# Print the average LOC
print(f"\nAverage LOC across all tasks: {average_loc:.2f}")
# Out:
# Task ID: HumanEval/0, LOC: 16
# Task ID: HumanEval/1, LOC: 35
# Task ID: HumanEval/2, LOC: 12
# Task ID: HumanEval/3, LOC: 10
# Task ID: HumanEval/4, LOC: 20
# Task ID: HumanEval/5, LOC: 16
# Task ID: HumanEval/6, LOC: 26
# Task ID: HumanEval/7, LOC: 11
# Task ID: HumanEval/8, LOC: 19
# Task ID: HumanEval/9, LOC: 15
# Task ID: HumanEval/10, LOC: 20
# Task ID: HumanEval/11, LOC: 16
# Task ID: HumanEval/12, LOC: 25
# Task ID: HumanEval/13, LOC: 10
# Task ID: HumanEval/14, LOC: 12
# Task ID: HumanEval/15, LOC: 8
# Task ID: HumanEval/16, LOC: 19
# Task ID: HumanEval/17, LOC: 28
# Task ID: HumanEval/18, LOC: 18
# Task ID: HumanEval/19, LOC: 34
# Task ID: HumanEval/20, LOC: 22
# Task ID: HumanEval/21, LOC: 20
# Task ID: HumanEval/22, LOC: 11
# Task ID: HumanEval/23, LOC: 8
# Task ID: HumanEval/24, LOC: 9
# Task ID: HumanEval/25, LOC: 25
# Task ID: HumanEval/26, LOC: 16
# Task ID: HumanEval/27, LOC: 14
# Task ID: HumanEval/28, LOC: 11
# Task ID: HumanEval/29, LOC: 11
# Task ID: HumanEval/30, LOC: 8
# Task ID: HumanEval/31, LOC: 23
# Task ID: HumanEval/32, LOC: 43
# Task ID: HumanEval/33, LOC: 24
# Task ID: HumanEval/34, LOC: 6
# Task ID: HumanEval/35, LOC: 14
# Task ID: HumanEval/36, LOC: 14
# Task ID: HumanEval/37, LOC: 14
# Task ID: HumanEval/38, LOC: 9
# Task ID: HumanEval/39, LOC: 32
# Task ID: HumanEval/40, LOC: 24
# Task ID: HumanEval/41, LOC: 13
# Task ID: HumanEval/42, LOC: 8
# Task ID: HumanEval/43, LOC: 21
# Task ID: HumanEval/44, LOC: 22
# Task ID: HumanEval/45, LOC: 7
# Task ID: HumanEval/46, LOC: 27
# Task ID: HumanEval/47, LOC: 15
# Task ID: HumanEval/48, LOC: 26
# Task ID: HumanEval/49, LOC: 21
# Task ID: HumanEval/50, LOC: 5
# Task ID: HumanEval/51, LOC: 18
# Task ID: HumanEval/52, LOC: 11
# Task ID: HumanEval/53, LOC: 8
# Task ID: HumanEval/54, LOC: 17
# Task ID: HumanEval/55, LOC: 15
# Task ID: HumanEval/56, LOC: 22
# Task ID: HumanEval/57, LOC: 12
# Task ID: HumanEval/58, LOC: 10
# Task ID: HumanEval/59, LOC: 14
# Task ID: HumanEval/60, LOC: 14
# Task ID: HumanEval/61, LOC: 22
# Task ID: HumanEval/62, LOC: 13
# Task ID: HumanEval/63, LOC: 23
# Task ID: HumanEval/64, LOC: 37
# Task ID: HumanEval/65, LOC: 17
# Task ID: HumanEval/66, LOC: 18
# Task ID: HumanEval/67, LOC: 21
# Task ID: HumanEval/68, LOC: 16
# Task ID: HumanEval/69, LOC: 28
# Task ID: HumanEval/70, LOC: 26
# Task ID: HumanEval/71, LOC: 23
# Task ID: HumanEval/72, LOC: 28
# Task ID: HumanEval/73, LOC: 19
# Task ID: HumanEval/74, LOC: 23
# Task ID: HumanEval/75, LOC: 25
# Task ID: HumanEval/76, LOC: 20
# Task ID: HumanEval/77, LOC: 21
# Task ID: HumanEval/78, LOC: 26
# Task ID: HumanEval/79, LOC: 14
# Task ID: HumanEval/80, LOC: 20
# Task ID: HumanEval/81, LOC: 31
# Task ID: HumanEval/82, LOC: 16
# Task ID: HumanEval/83, LOC: 9
# Task ID: HumanEval/84, LOC: 21
# Task ID: HumanEval/85, LOC: 12
# Task ID: HumanEval/86, LOC: 21
# Task ID: HumanEval/87, LOC: 11
# Task ID: HumanEval/88, LOC: 33
# Task ID: HumanEval/89, LOC: 21
# Task ID: HumanEval/90, LOC: 25
# Task ID: HumanEval/91, LOC: 23
# Task ID: HumanEval/92, LOC: 25
# Task ID: HumanEval/93, LOC: 33
# Task ID: HumanEval/94, LOC: 22
# Task ID: HumanEval/95, LOC: 21
# Task ID: HumanEval/96, LOC: 20
# Task ID: HumanEval/97, LOC: 13
# Task ID: HumanEval/98, LOC: 17
# Task ID: HumanEval/99, LOC: 27
# Task ID: HumanEval/100, LOC: 27
# Task ID: HumanEval/101, LOC: 16
# Task ID: HumanEval/102, LOC: 20
# Task ID: HumanEval/103, LOC: 19
# Task ID: HumanEval/104, LOC: 17
# Task ID: HumanEval/105, LOC: 27
# Task ID: HumanEval/106, LOC: 14
# Task ID: HumanEval/107, LOC: 16
# Task ID: HumanEval/108, LOC: 18
# Task ID: HumanEval/109, LOC: 38
# Task ID: HumanEval/110, LOC: 20
# Task ID: HumanEval/111, LOC: 35
# Task ID: HumanEval/112, LOC: 9
# Task ID: HumanEval/113, LOC: 17
# Task ID: HumanEval/114, LOC: 16
# Task ID: HumanEval/115, LOC: 12
# Task ID: HumanEval/116, LOC: 15
# Task ID: HumanEval/117, LOC: 20
# Task ID: HumanEval/118, LOC: 23
# Task ID: HumanEval/119, LOC: 29
# Task ID: HumanEval/120, LOC: 30
# Task ID: HumanEval/121, LOC: 13
# Task ID: HumanEval/122, LOC: 19
# Task ID: HumanEval/123, LOC: 27
# Task ID: HumanEval/124, LOC: 58
# Task ID: HumanEval/125, LOC: 17
# Task ID: HumanEval/126, LOC: 26
# Task ID: HumanEval/127, LOC: 24
# Task ID: HumanEval/128, LOC: 30
# Task ID: HumanEval/129, LOC: 19
# Task ID: HumanEval/130, LOC: 30
# Task ID: HumanEval/131, LOC: 19
# Task ID: HumanEval/132, LOC: 12
# Task ID: HumanEval/133, LOC: 14
# Task ID: HumanEval/134, LOC: 25
# Task ID: HumanEval/135, LOC: 17
# Task ID: HumanEval/136, LOC: 19
# Task ID: HumanEval/137, LOC: 25
# Task ID: HumanEval/138, LOC: 21
# Task ID: HumanEval/139, LOC: 19
# Task ID: HumanEval/140, LOC: 20
# Task ID: HumanEval/141, LOC: 25
# Task ID: HumanEval/142, LOC: 20
# Task ID: HumanEval/143, LOC: 31
# Task ID: HumanEval/144, LOC: 25
# Task ID: HumanEval/145, LOC: 15
# Task ID: HumanEval/146, LOC: 6
# Task ID: HumanEval/147, LOC: 24
# Task ID: HumanEval/148, LOC: 29
# Task ID: HumanEval/149, LOC: 8
# Task ID: HumanEval/150, LOC: 17
# Task ID: HumanEval/151, LOC: 17
# Task ID: HumanEval/152, LOC: 6
# Task ID: HumanEval/153, LOC: 8
# Task ID: HumanEval/154, LOC: 22
# Task ID: HumanEval/155, LOC: 18
# Task ID: HumanEval/156, LOC: 21
# Task ID: HumanEval/157, LOC: 18
# Task ID: HumanEval/158, LOC: 25
# Task ID: HumanEval/159, LOC: 33
# Task ID: HumanEval/160, LOC: 30
# Task ID: HumanEval/161, LOC: 28
# Task ID: HumanEval/162, LOC: 14
# Task ID: HumanEval/163, LOC: 18
#
# Average LOC across all tasks: 19.66
